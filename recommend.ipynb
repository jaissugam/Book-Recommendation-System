# %%
import numpy as np
import pandas as pd
import pickle
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
df=pd.read_csv('books.csv')
df.head()
# Out:
#           isbn13      isbn10           title subtitle  \
# 0  9780002005883  0002005883          Gilead      NaN
# 1  9780002261982  0002261987    Spider's Web  A Novel
# 2  9780006163831  0006163831    The One Tree      NaN
# 3  9780006178736  0006178731  Rage of angels      NaN
# 4  9780006280897  0006280897  The Four Loves      NaN
#
#                            authors                     categories  \
# 0               Marilynne Robinson                        Fiction
# 1  Charles Osborne;Agatha Christie  Detective and mystery stories
# 2             Stephen R. Donaldson               American fiction
# 3                   Sidney Sheldon                        Fiction
# 4              Clive Staples Lewis                 Christian life
#
#                                            thumbnail  \
# 0  http://books.google.com/books/content?id=KQZCP...
# 1  http://books.google.com/books/content?id=gA5GP...
# 2  http://books.google.com/books/content?id=OmQaw...
# 3  http://books.google.com/books/content?id=FKo2T...
# 4  http://books.google.com/books/content?id=XhQ5X...
#
#                                          description  published_year  \
# 0  A NOVEL THAT READERS and critics have been eag...          2004.0
# 1  A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2  Volume Two of Stephen Donaldson's acclaimed se...          1982.0
# 3  A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 4  Lewis' work on the nature of love divides love...          2002.0
#
#    average_rating  num_pages  ratings_count
# 0            3.85      247.0          361.0
# 1            3.83      241.0         5164.0
# 2            3.97      479.0          172.0
# 3            3.93      512.0        29532.0
# 4            4.15      170.0        33684.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6810 entries, 0 to 6809
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   isbn13          6810 non-null   int64
#  1   isbn10          6810 non-null   object
#  2   title           6810 non-null   object
#  3   subtitle        2381 non-null   object
#  4   authors         6738 non-null   object
#  5   categories      6711 non-null   object
#  6   thumbnail       6481 non-null   object
#  7   description     6548 non-null   object
#  8   published_year  6804 non-null   float64
#  9   average_rating  6767 non-null   float64
#  10  num_pages       6767 non-null   float64
#  11  ratings_count   6767 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 638.6+ KB

# %%
books=df.drop(columns=['isbn10','subtitle','thumbnail','published_year','num_pages'])
books.head()
# Out:
#           isbn13           title                          authors  \
# 0  9780002005883          Gilead               Marilynne Robinson
# 1  9780002261982    Spider's Web  Charles Osborne;Agatha Christie
# 2  9780006163831    The One Tree             Stephen R. Donaldson
# 3  9780006178736  Rage of angels                   Sidney Sheldon
# 4  9780006280897  The Four Loves              Clive Staples Lewis
#
#                       categories  \
# 0                        Fiction
# 1  Detective and mystery stories
# 2               American fiction
# 3                        Fiction
# 4                 Christian life
#
#                                          description  average_rating  \
# 0  A NOVEL THAT READERS and critics have been eag...            3.85
# 1  A new 'Christie for Christmas' -- a full-lengt...            3.83
# 2  Volume Two of Stephen Donaldson's acclaimed se...            3.97
# 3  A memorable, mesmerizing heroine Jennifer -- b...            3.93
# 4  Lewis' work on the nature of love divides love...            4.15
#
#    ratings_count
# 0          361.0
# 1         5164.0
# 2          172.0
# 3        29532.0
# 4        33684.0

# %%
books['popularity']=(books['average_rating']*books['ratings_count'])/100000
books.head()
# Out:
#           isbn13           title                          authors  \
# 0  9780002005883          Gilead               Marilynne Robinson
# 1  9780002261982    Spider's Web  Charles Osborne;Agatha Christie
# 2  9780006163831    The One Tree             Stephen R. Donaldson
# 3  9780006178736  Rage of angels                   Sidney Sheldon
# 4  9780006280897  The Four Loves              Clive Staples Lewis
#
#                       categories  \
# 0                        Fiction
# 1  Detective and mystery stories
# 2               American fiction
# 3                        Fiction
# 4                 Christian life
#
#                                          description  average_rating  \
# 0  A NOVEL THAT READERS and critics have been eag...            3.85
# 1  A new 'Christie for Christmas' -- a full-lengt...            3.83
# 2  Volume Two of Stephen Donaldson's acclaimed se...            3.97
# 3  A memorable, mesmerizing heroine Jennifer -- b...            3.93
# 4  Lewis' work on the nature of love divides love...            4.15
#
#    ratings_count  popularity
# 0          361.0    0.013899
# 1         5164.0    0.197781
# 2          172.0    0.006828
# 3        29532.0    1.160608
# 4        33684.0    1.397886

# %%
books.dropna(inplace=True)
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6412 entries, 0 to 6809
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   isbn13          6412 non-null   int64
#  1   title           6412 non-null   object
#  2   authors         6412 non-null   object
#  3   categories      6412 non-null   object
#  4   description     6412 non-null   object
#  5   average_rating  6412 non-null   float64
#  6   ratings_count   6412 non-null   float64
#  7   popularity      6412 non-null   float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 450.8+ KB

# %%
books.describe()
# Out:
#              isbn13  average_rating  ratings_count   popularity
# count  6.412000e+03     6412.000000   6.412000e+03  6412.000000
# mean   9.780665e+12        3.931648   2.195072e+04     0.886942
# std    5.806764e+08        0.322645   1.412383e+05     5.845063
# min    9.780002e+12        0.000000   0.000000e+00     0.000000
# 25%    9.780316e+12        3.770000   1.767500e+02     0.006892
# 50%    9.780522e+12        3.950000   1.087000e+03     0.042899
# 75%    9.780806e+12        4.130000   6.443250e+03     0.253530
# max    9.789042e+12        5.000000   5.629932e+06   251.657960

# %%
(books['popularity']>0.001).sum()
# Out:
# 5889

# %%
def changeRating(num):
    new='badr'
    if num>=0.001 and num<0.01:
        new='lowr'
    elif num>=0.01 and num<0.1:
        new='poorr'
    elif num>=0.1 and num<1:
        new='decentr'
    elif num>=1 and num<10:
        new='goodr'
    elif num>=10 and num<50:
        new='outstandingr'
    elif num>=50:
        new='greatr'
    return new

# %%
books['popularity']=books['popularity'].apply(changeRating)

# %%
books.head(10)
# Out:
#           isbn13                   title                          authors  \
# 0  9780002005883                  Gilead               Marilynne Robinson
# 1  9780002261982            Spider's Web  Charles Osborne;Agatha Christie
# 2  9780006163831            The One Tree             Stephen R. Donaldson
# 3  9780006178736          Rage of angels                   Sidney Sheldon
# 4  9780006280897          The Four Loves              Clive Staples Lewis
# 5  9780006280934     The Problem of Pain              Clive Staples Lewis
# 6  9780006353287        An Autobiography                  Agatha Christie
# 7  9780006380832  Empires of the Monsoon                     Richard Hall
# 8  9780006470229    The Gap Into Madness             Stephen R. Donaldson
# 9  9780006472612      Master of the Game                   Sidney Sheldon
#
#                             categories  \
# 0                              Fiction
# 1        Detective and mystery stories
# 2                     American fiction
# 3                              Fiction
# 4                       Christian life
# 5                       Christian life
# 6                     Authors, English
# 7                         Africa, East
# 8  Hyland, Morn (Fictitious character)
# 9                    Adventure stories
#
#                                          description  average_rating  \
# 0  A NOVEL THAT READERS and critics have been eag...            3.85
# 1  A new 'Christie for Christmas' -- a full-lengt...            3.83
# 2  Volume Two of Stephen Donaldson's acclaimed se...            3.97
# 3  A memorable, mesmerizing heroine Jennifer -- b...            3.93
# 4  Lewis' work on the nature of love divides love...            4.15
# 5  "In The Problem of Pain, C.S. Lewis, one of th...            4.09
# 6                                          Donation.            4.27
# 7  Until Vasco da Gama discovered the sea-route t...            4.41
# 8  A new-cover reissue of the fourth book in the ...            4.15
# 9  Kate Blackwell is an enigma and one of the mos...            4.11
#
#    ratings_count popularity
# 0          361.0      poorr
# 1         5164.0    decentr
# 2          172.0       lowr
# 3        29532.0      goodr
# 4        33684.0      goodr
# 5        37569.0      goodr
# 6         3975.0    decentr
# 7           65.0       lowr
# 8          103.0       lowr
# 9        43540.0      goodr

# %%
books=books.drop(columns=['average_rating','ratings_count'])

# %%
import re
def makeLists(text):
    results=re.split(';|&|and|\*|\n', text)
    lists=[]
    for r in results:
        lists.append((r.replace(" ","")).lower())
    return lists

# %%
books['authors']=books['authors'].apply(makeLists)
books['categories']=books['categories'].apply(makeLists)

# %%
books['popularity']=books['popularity'].apply(lambda a:a.split())

# %%
from nltk.stem.porter import PorterStemmer
def changeDescription(text):
    res=text.lower()
    res=re.sub(r'[^\w]', ' ', res)
    l=[]
    ps=PorterStemmer()
    for word in res.split():
        l.append(ps.stem(word))
    return l

# %%
books['description']=books['description'].apply(changeDescription)

# %%
books['label']=books['authors']+books['categories']+books['description']+books['popularity']

# %%
books=books.drop(columns=['authors','categories','description','popularity'])

# %%
books['label']=books['label'].apply(lambda w:" ".join(w))
books.head()
# Out:
#           isbn13           title  \
# 0  9780002005883          Gilead
# 1  9780002261982    Spider's Web
# 2  9780006163831    The One Tree
# 3  9780006178736  Rage of angels
# 4  9780006280897  The Four Loves
#
#                                                label
# 0  marilynnerobinson fiction a novel that reader ...
# 1  charlesosborne agathachristie detective myster...
# 2  stephenr.donaldson americanfiction volum two o...
# 3  sidneysheldon fiction a memor mesmer heroin je...
# 4  clivestapleslewis christianlife lewi work on t...

# %%
vect=CountVectorizer(max_features=4000,stop_words='english')
vector=vect.fit_transform(books['label']).toarray()
vector.shape
# Out:
# (6412, 4000)

# %%
proximityVector=cosine_similarity(vector)
proximityVector
# Out:
# array([[1.        , 0.02503915, 0.        , ..., 0.24286823, 0.07109956,
#         0.        ],
#        [0.02503915, 1.        , 0.02397317, ..., 0.07644956, 0.07121091,
#         0.02397317],
#        [0.        , 0.02397317, 1.        , ..., 0.0265747 , 0.02475369,
#         0.        ],
#        ...,
#        [0.24286823, 0.07644956, 0.0265747 , ..., 1.        , 0.11051407,
#         0.1062988 ],
#        [0.07109956, 0.07121091, 0.02475369, ..., 0.11051407, 1.        ,
#         0.02475369],
#        [0.        , 0.02397317, 0.        , ..., 0.1062988 , 0.02475369,
#         1.        ]])
